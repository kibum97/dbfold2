# %% [markdown]
# # 1D Free energy plot
#
# This notebook shows a way to plot 1D free energy plot using the free energy computed from dbfold package. Output of dbfold fes analysis should be saved as pickle file to be compatible with the methods below. Otherwise, please modify the code so that free energy results can be formatted in a way that plotting parts can recognize.

# %%
import dbfold
import pickle

# %%
data_path = '/n/home01/kibumpark/group_folder/p19__Actin/Analysis/results/'
data_dict = pickle.load(open(data_path,'rb'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 data_path = '/n/home01/kibumpark/group_folder/p19__Actin/Analysis/results/'
# ----> 2 result = pickle.load(data_path)
#
# TypeError: file must have 'read' and 'readline' attributes
