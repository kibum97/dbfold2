# %%
import mdtraj as md

# %%
traj = md.load('abce1.pdb')
# Out:
# /n/home01/kibumpark/.conda/envs/dbfold2/lib/python3.10/site-packages/mdtraj/formats/pdb/pdbfile.py:206: UserWarning: Unlikely unit cell vectors detected in PDB file likely resulting from a dummy CRYST1 record. Discarding unit cell vectors.
#   warnings.warn(

# %%
traj = traj.atom_slice(traj.topology.select('element != H'))
traj
# Out:
# <mdtraj.Trajectory with 1 frames, 4721 atoms, 599 residues, without unitcells at 0x1518a75f3bb0>

# %%
traj.save('abce1_noH.pdb')
